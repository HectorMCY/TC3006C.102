# %% [markdown]
# Regresión Lineal con Iris data

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# Checamos qie no haya valores nulos

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# Quitamos la informaciópn del ID

# %%
df.drop('Id', axis=1, inplace=True)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# Creamos variabled dicotómicas

# %%
dummies = pd.get_dummies(df['Species'], prefix= 'Species')

# %%
dummies
# Out:
#      Species_Iris-setosa  Species_Iris-versicolor  Species_Iris-virginica
# 0                      1                        0                       0
# 1                      1                        0                       0
# 2                      1                        0                       0
# 3                      1                        0                       0
# 4                      1                        0                       0
# ..                   ...                      ...                     ...
# 145                    0                        0                       1
# 146                    0                        0                       1
# 147                    0                        0                       1
# 148                    0                        0                       1
# 149                    0                        0                       1
#
# [150 rows x 3 columns]

# %%
df=pd.concat([df, dummies], axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
#      Species_Iris-setosa  Species_Iris-versicolor  Species_Iris-virginica
# 0                      1                        0                       0
# 1                      1                        0                       0
# 2                      1                        0                       0
# 3                      1                        0                       0
# 4                      1                        0                       0
# ..                   ...                      ...                     ...
# 145                    0                        0                       1
# 146                    0                        0                       1
# 147                    0                        0                       1
# 148                    0                        0                       1
# 149                    0                        0                       1
#
# [150 rows x 8 columns]

# %% [markdown]
# Reemplazamos los guiones en los nombres para que pueda correr en Python

# %%
df.rename(columns ={'Species_Iris-setosa':'Species_setosa'}, inplace=True)
df.rename(columns ={'Species_Iris-versicolor':'Species_versicolor'}, inplace=True)
df.rename(columns ={'Species_Iris-virginica':'Species_virginica'}, inplace=True)

# %% [markdown]
# Sacamos la correlación (Si están correlacionados de acuerdo con la tabla de abajo)

# %%
correlacion = df.corr()
# Out:
# <ipython-input-57-c0854e3b5557>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlacion = df.corr()

# %%
alta_corr = np.where((correlacion>0.95) & (correlacion<1))
alta_corr
# Out:
# (array([2, 3]), array([3, 2]))

# %%
correlacion
# Out:
#                     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# SepalLengthCm            1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm            -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm            0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm             0.817954     -0.356544       0.962757      1.000000
# Species_setosa          -0.717416      0.595601      -0.922688     -0.887510
# Species_versicolor       0.079396     -0.464700       0.201587      0.118376
# Species_virginica        0.638020     -0.130901       0.721102      0.769134
#
#                     Species_setosa  Species_versicolor  Species_virginica
# SepalLengthCm            -0.717416            0.079396           0.638020
# SepalWidthCm              0.595601           -0.464700          -0.130901
# PetalLengthCm            -0.922688            0.201587           0.721102
# PetalWidthCm             -0.887510            0.118376           0.769134
# Species_setosa            1.000000           -0.500000          -0.500000
# Species_versicolor       -0.500000            1.000000          -0.500000
# Species_virginica        -0.500000           -0.500000           1.000000

# %%
baja_corr = np.where((correlacion<-0.95) & (correlacion>-1))
baja_corr
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# Estadarizamos los datos

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %% [markdown]
# Quitamos la columna Species

# %%
df.drop('Species', axis=1, inplace=True)

# %%
df_estandard=scaler.fit_transform(df)
df_estandard
# Out:
# array([[-0.90068117,  1.03205722, -1.3412724 , ...,  1.41421356,
#         -0.70710678, -0.70710678],
#        [-1.14301691, -0.1249576 , -1.3412724 , ...,  1.41421356,
#         -0.70710678, -0.70710678],
#        [-1.38535265,  0.33784833, -1.39813811, ...,  1.41421356,
#         -0.70710678, -0.70710678],
#        ...,
#        [ 0.79566902, -0.1249576 ,  0.81962435, ..., -0.70710678,
#         -0.70710678,  1.41421356],
#        [ 0.4321654 ,  0.80065426,  0.93335575, ..., -0.70710678,
#         -0.70710678,  1.41421356],
#        [ 0.06866179, -0.1249576 ,  0.76275864, ..., -0.70710678,
#         -0.70710678,  1.41421356]])

# %% [markdown]
# Lo tenemos que convertir ahora a DataFrame

# %%
df_estandard = pd.DataFrame(df_estandard, columns = df.columns)
df_estandard
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species_setosa  \
# 0        -0.900681      1.032057      -1.341272     -1.312977        1.414214
# 1        -1.143017     -0.124958      -1.341272     -1.312977        1.414214
# 2        -1.385353      0.337848      -1.398138     -1.312977        1.414214
# 3        -1.506521      0.106445      -1.284407     -1.312977        1.414214
# 4        -1.021849      1.263460      -1.341272     -1.312977        1.414214
# ..             ...           ...            ...           ...             ...
# 145       1.038005     -0.124958       0.819624      1.447956       -0.707107
# 146       0.553333     -1.281972       0.705893      0.922064       -0.707107
# 147       0.795669     -0.124958       0.819624      1.053537       -0.707107
# 148       0.432165      0.800654       0.933356      1.447956       -0.707107
# 149       0.068662     -0.124958       0.762759      0.790591       -0.707107
#
#      Species_versicolor  Species_virginica
# 0             -0.707107          -0.707107
# 1             -0.707107          -0.707107
# 2             -0.707107          -0.707107
# 3             -0.707107          -0.707107
# 4             -0.707107          -0.707107
# ..                  ...                ...
# 145           -0.707107           1.414214
# 146           -0.707107           1.414214
# 147           -0.707107           1.414214
# 148           -0.707107           1.414214
# 149           -0.707107           1.414214
#
# [150 rows x 7 columns]

# %% [markdown]
# Dividimos la base de datos en los datos que se van a usar para entrenamiento y prueba

# %%
from sklearn.model_selection import train_test_split
entrenamiento, prueba = train_test_split(df_estandard, test_size=0.20, random_state=42)

# %%
entrenamiento
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species_setosa  \
# 22       -1.506521      1.263460      -1.568735     -1.312977        1.414214
# 15       -0.173674      3.114684      -1.284407     -1.050031        1.414214
# 65        1.038005      0.106445       0.364699      0.264699       -0.707107
# 11       -1.264185      0.800654      -1.227541     -1.312977        1.414214
# 42       -1.748856      0.337848      -1.398138     -1.312977        1.414214
# ..             ...           ...            ...           ...             ...
# 71        0.310998     -0.587764       0.137236      0.133226       -0.707107
# 106      -1.143017     -1.281972       0.421564      0.659118       -0.707107
# 14       -0.052506      2.189072      -1.455004     -1.312977        1.414214
# 92       -0.052506     -1.050569       0.137236      0.001753       -0.707107
# 102       1.522676     -0.124958       1.217684      1.185010       -0.707107
#
#      Species_versicolor  Species_virginica
# 22            -0.707107          -0.707107
# 15            -0.707107          -0.707107
# 65             1.414214          -0.707107
# 11            -0.707107          -0.707107
# 42            -0.707107          -0.707107
# ..                  ...                ...
# 71             1.414214          -0.707107
# 106           -0.707107           1.414214
# 14            -0.707107          -0.707107
# 92             1.414214          -0.707107
# 102           -0.707107           1.414214
#
# [120 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species_setosa', 'Species_versicolor', 'Species_virginica'],
#       dtype='object')

# %%
import statsmodels.formula.api as smf
modelo = smf.ols(formula='SepalLengthCm~SepalWidthCm+PetalLengthCm+PetalWidthCm+Species_setosa+Species_versicolor', data=entrenamiento)
modelo = modelo.fit()
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          SepalLengthCm   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.859
# Method:                 Least Squares   F-statistic:                     145.7
# Date:                Fri, 11 Aug 2023   Prob (F-statistic):           8.28e-48
# Time:                        23:43:45   Log-Likelihood:                -49.544
# No. Observations:                 120   AIC:                             111.1
# Df Residuals:                     114   BIC:                             127.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             -0.0227      0.034     -0.661      0.510      -0.091       0.045
# SepalWidthCm           0.2734      0.052      5.220      0.000       0.170       0.377
# PetalLengthCm          1.8574      0.170     10.948      0.000       1.521       2.194
# PetalWidthCm          -0.4296      0.156     -2.763      0.007      -0.738      -0.122
# Species_setosa         0.5349      0.221      2.417      0.017       0.096       0.973
# Species_versicolor     0.1642      0.076      2.166      0.032       0.014       0.314
# ==============================================================================
# Omnibus:                        0.762   Durbin-Watson:                   2.288
# Prob(Omnibus):                  0.683   Jarque-Bera (JB):                0.886
# Skew:                          -0.136   Prob(JB):                        0.642
# Kurtosis:                       2.678   Cond. No.                         14.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_aprox = 0+0.2734*prueba['SepalWidthCm']+1.8574*prueba['PetalLengthCm']-0.4296*prueba['PetalWidthCm']+0.5349*prueba['Species_setosa']+0.1642*prueba['Species_versicolor']
y_aprox
# Out:
# 73     0.686793
# 18    -0.554521
# 118    1.914345
# 78     0.369372
# 76     0.679454
# 31    -1.075309
# 64    -0.468268
# 141    0.329470
# 68    -0.073487
# 82    -0.221451
# 110    0.562178
# 12    -1.264551
# 36    -1.110327
# 9     -1.095663
# 19    -0.765766
# 56     0.777198
# 104    1.062042
# 69    -0.291502
# 55     0.419068
# 132    0.724266
# 29    -0.983256
# 127    0.337364
# 26    -0.969687
# 128    0.780747
# 131    2.314862
# 145    0.371827
# 108    0.971637
# 143    1.237714
# 45    -1.377513
# 30    -1.046522
# dtype: float64

# %%
tabla = pd.DataFrame({'Real': prueba['SepalLengthCm'], 'Prediccion': y_aprox, 'Errores': prueba['SepalLengthCm']-y_aprox})
tabla
# Out:
#          Real  Prediccion   Errores
# 73   0.310998    0.686793 -0.375796
# 18  -0.173674   -0.554521  0.380847
# 118  2.249683    1.914345  0.335339
# 78   0.189830    0.369372 -0.179542
# 76   1.159173    0.679454  0.479719
# 31  -0.537178   -1.075309  0.538131
# 64  -0.294842   -0.468268  0.173426
# 141  1.280340    0.329470  0.950871
# 68   0.432165   -0.073487  0.505653
# 82  -0.052506   -0.221451  0.168945
# 110  0.795669    0.562178  0.233491
# 12  -1.264185   -1.264551  0.000367
# 36  -0.416010   -1.110327  0.694317
# 9   -1.143017   -1.095663 -0.047354
# 19  -0.900681   -0.765766 -0.134915
# 56   0.553333    0.777198 -0.223865
# 104  0.795669    1.062042 -0.266373
# 69  -0.294842   -0.291502 -0.003340
# 55  -0.173674    0.419068 -0.592742
# 132  0.674501    0.724266 -0.049765
# 29  -1.385353   -0.983256 -0.402096
# 127  0.310998    0.337364 -0.026366
# 26  -1.021849   -0.969687 -0.052162
# 128  0.674501    0.780747 -0.106245
# 131  2.492019    2.314862  0.177157
# 145  1.038005    0.371827  0.666178
# 108  1.038005    0.971637  0.066368
# 143  1.159173    1.237714 -0.078542
# 45  -1.264185   -1.377513  0.113328
# 30  -1.264185   -1.046522 -0.217663

# %% [markdown]
# Vamos a graficar los datos reales contra la predicción

# %%
import matplotlib.pyplot as plt
plt.scatter(prueba['SepalLengthCm'], y_aprox, color='gray')
plt.plot(prueba['SepalLengthCm'], prueba['SepalLengthCm'], color = 'red')
plt.xlabel('Datos Reales')
plt.ylabel('Prediccion')
# Out:
# Text(0, 0.5, 'Prediccion')

# %% [markdown]
# Calcular que los residuos sean igual a zero
# Primero sacamos la cantidad de residuos(errores)

# %%
l_residuos = len(tabla['Errores'])

# %%
plt.scatter(range(l_residuos), tabla['Errores'], color = 'gray')
plt.axhline(y=0,linestyle='--',color='black')
plt.xlabel('Número del Residuo')
plt.ylabel('Valor del Residuo')
# Out:
# Text(0, 0.5, 'Valor del Residuo')

# %% [markdown]
# Hacemos el Histograma

# %%
plt.hist(x=tabla['Errores'], color = 'orange')
plt.title('Histograma Residuos')
plt.xlabel('Residuos')
plt.ylabel('Frecuencia (Probabilidad)')
# Out:
# Text(0, 0.5, 'Frecuencia (Probabilidad)')

# %%
import statsmodels.api as sm
from scipy import stats
QQ = sm.qqplot(tabla['Errores'], stats.norm, line = '45')

# %% [markdown]
# Estandarizamos los Residuos

# %%
media = tabla['Errores'].mean()
std = tabla['Errores'].std()
Errores_est = (tabla['Errores']-media)/std

# %% [markdown]
# Test de Kolmogorov Smearnof

# %%
import statsmodels.api as sm
from scipy import stats
stats.kstest(Errores_est, 'norm')
# Out:
# KstestResult(statistic=0.13371601636027958, pvalue=0.6095294211476956, statistic_location=-0.25433775542243403, statistic_sign=1)
